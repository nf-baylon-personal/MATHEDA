# %% [markdown]
# # Pandas Basics <hr style="border:2.5px solid #fce100"></hr>

# %% [markdown]
# <b> Norbert Francis C. Baylon </b>
# <br>Computer Engineering Student
# <br> Technological University of the Philippines Visayas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # DataFrame

# %%
data = {
    "Name":['Henry','Owen','Ada'],
    "Age":[22,35,58],
    "Sex":['M','M','F']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ada   58   F

# %% [markdown]
# # Series

# %%
df['Name']
# Out:
# 0    Henry
# 1     Owen
# 2      Ada
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df['Sex']
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
resistance = np.array([
    [3,9.1,9.3,9.5,9.8,9.8,10.4,10.4,10.5,10.5,11], #Dataset 1/Jaguar
    [9.1,9.1,9.1,9.2,9.2,9.9,10.1,10.8,11,20, np.nan] #Dataset 2/Panther
]).T
resistance
# Out:
# array([[ 3. ,  9.1],
#        [ 9.1,  9.1],
#        [ 9.3,  9.1],
#        [ 9.5,  9.2],
#        [ 9.8,  9.2],
#        [ 9.8,  9.9],
#        [10.4, 10.1],
#        [10.4, 10.8],
#        [10.5, 11. ],
#        [10.5, 20. ],
#        [11. ,  nan]])

# %%
df = pd.DataFrame(resistance, columns = ['Jaguar','Panther'])
df
# Out:
#     Jaguar  Panther
# 0      3.0      9.1
# 1      9.1      9.1
# 2      9.3      9.1
# 3      9.5      9.2
# 4      9.8      9.2
# 5      9.8      9.9
# 6     10.4     10.1
# 7     10.4     10.8
# 8     10.5     11.0
# 9     10.5     20.0
# 10    11.0      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    9.390909  10.750000
# std     2.199297   3.329081
# min     3.000000   9.100000
# 25%     9.400000   9.125000
# 50%     9.800000   9.550000
# 75%    10.450000  10.625000
# max    11.000000  20.000000

# %%
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

print(f'Jaguar Median = {jag_median:.2f} ohms')
print(f'Panther Median = {pan_median:.2f} ohms')
# Out:
# Jaguar Median = 9.80 ohms
# Panther Median = 9.55 ohms

# %%
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

# %%
jag_mode
# Out:
# 0     9.8
# 1    10.4
# 2    10.5
# Name: Jaguar, dtype: float64

# %%
jag_mode.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: Jaguar
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      float64
# dtypes: float64(1)
# memory usage: 156.0 bytes

# %%
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print('Jaguar Mode')

for i in jag_mode:
    print(i)
# Out:
# Jaguar Mode
# 9.8
# 10.4
# 10.5

# %%
print('Panther Mode')

for i in pan_mode:
    print(i)
# Out:
# Panther Mode
# 9.1

# %%
jQ1 = df['Jaguar'].quantile(0.25)
jQ3 = df['Jaguar'].quantile(0.75)

print(f'Jaguar IQR = {jQ3-jQ1:.2f} ohms')
# Out:
# Jaguar IQR = 1.05 ohms

# %%
pQ1 = df['Panther'].quantile(0.25)
pQ3 = df['Panther'].quantile(0.75)

print(f'Panther IQR = {pQ3-pQ1:.2f} ohms')
# Out:
# Panther IQR = 1.50 ohms

# %% [markdown]
# # Bar Chart

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
bars = plt.bar(['Jaguar', 'Panther'], [jag_mean,pan_mean],
               color='#fce300')
plt.title('Average Resistance by Machine')
plt.ylabel('Resistance (ohms)')

plt.bar_label(bars,padding=3)
plt.margins(y=0.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
