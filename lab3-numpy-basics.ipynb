# %% [markdown]
# # Numpy <hr style="border:2.5px solid #fce100"></hr>

# %% [markdown]
# <b> Norbert Francis C. Baylon </b>
# <br>Computer Engineering Student
# <br> Technological University of the Philippines Visayas

# %%
import numpy as np

# %% [markdown]
# # 1-D Array

# %%
my_array = np.array([1,2,3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# # 2-D Array

# %%
my_array = np.array([
    [1,2,3],
    [4,5,6]
])
my_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.shape(my_array)
# Out:
# (2, 3)

# %%
trans_array = my_array.T

# %%
np.shape(trans_array)
# Out:
# (3, 2)

# %%
trans_array
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.sum(trans_array,axis=0)
# Out:
# array([ 6, 15])

# %%
np.sum(trans_array,axis=1)
# Out:
# array([5, 7, 9])

# %% [markdown]
# # Measure of Central Tendency

# %%
resistance = np.array([
    [3,9.1,9.3,9.5,9.8,9.8,10.4,10.4,10.5,10.5,11], #Dataset 1/Jaguar
    [9.1,9.1,9.1,9.2,9.2,9.9,9.9,10.1,10.8,11,20] #Dataset 2/Panther
])

# %%
resistance
# Out:
# array([[ 3. ,  9.1,  9.3,  9.5,  9.8,  9.8, 10.4, 10.4, 10.5, 10.5, 11. ],
#        [ 9.1,  9.1,  9.1,  9.2,  9.2,  9.9,  9.9, 10.1, 10.8, 11. , 20. ]])

# %%
np.mean(resistance, axis = 1)
# Out:
# array([ 9.39090909, 10.67272727])

# %%
np.median(resistance, axis = 1)
# Out:
# array([9.8, 9.9])
